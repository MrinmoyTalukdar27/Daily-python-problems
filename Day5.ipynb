# %% [markdown]
# Straing

# %%
# positive indexing 
# use to access straing char from left to right
s="Hello"
print(s[2])

# Nagative Indexing
# use to access strings char from last element
M="world"
print(M[-3])
# Out:
# l
# r

# %%
# Slicing in straing
