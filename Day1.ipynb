# %%
print('hello world')
# Out:
# hello world

# %%
# find the sum of two numbers input by the user
f_num=input('enterthe first number')
s_num=input('enter the secound number')
result=int(f_num) +int(s_num)
print(result)
print(type(f_num))
# Out:
# 30
# <class 'str'>

# %%
#find the sum of 3 digit number enter by the user
number=int(input("enter a number"))
# here we are using reminder operator to get the reminder so that we get the last number
# beacuse we get the last digit of any number when we divide it by 10
a= number%10
#now we are using the int divison operator so that we can the next number from right side
# Beacus wheebn use divide any number with 10m using int divide we get result in point like 123//10
# we will get 12.3 so the // operator automatically convert that result into 12
# now we can see that we get last two number from the three digit number 
#it happand with all the numbers 
number=number//10

b=number%10
#we repeat the same steps afgin and agin top get the last number
number=number//10
c=number%10
#now we sum the three number and print them
print(a+b+c)
# Out:
# 6

# %%
# write a login program and indentatiom
#where email=mrinmoy@gmail.com
#where password=123
Email=input('enter a email')
password=input('enter your password')
if Email=='mrinmoy@gmail.com' and password =='123' :
   print( "welcome to the page")
else:
    print=("incorrect user or password")
# Out:
# welcome to the page

# %%
# Now we will see how to tell the user if there password or email is incorrect and
# how can we  give them another chance to correct his password or email
#using elif and nested if-else statement
email=input("'enetr your email")
password=input("enter your password")
if email=='mrinmoy@gmail.com' and password=='123':
    print=('welcome to the page')
elif email=='mrinmoy@gmailcom' and password !='123':
    print('enter the password agin')
    password=input('enter the password agin')
    if password !='123':
        print("No you cant login")
    else:
        print('welcome to the page ,finally')
else:
    print('incorrect password and email')
# Out:
# enter the password agin
# welcome to the page ,finally

# %%
#we need to find the smallest number between 3 numbers using if-else statement
a=int(input('enter the first number'))
b=int(input('enter the secound number'))
c=int(input('enter the third number'))
if a<b and a<c:
    print('smallest number',a)
elif b<c:
    print('snallest is', b)
else:
    print('smallest is',c)
# Out:
# snallest is 22
