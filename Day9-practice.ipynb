# %%
# Simply importing the library 
import numpy as np

# %%
# just generating random numbers for actual and predecited values
actual=np.random.randint(1,50,25)
predicated =np.random.randint(1,50,25)

# %%
# here we are simplay implementing the mean squre error function
def mes(actual,predicated):
    return np.mean((actual-predicated)**2)
mes(actual,predicated)
# Out:
# np.float64(514.84)

# %% [markdown]
# ##### working with missing values

# %%
a=np.array([1,2,3,np.nan,5])
a
# Out:
# array([ 1.,  2.,  3., nan,  5.])

# %%
#now we need to access all the element except the nan value from the array
a[~np.isnan(a)]
# Out:
# array([1., 2., 3., 5.])

# %% [markdown]
# #### Now we will see how we plot graphs in numpy

# %%
import matplotlib.pyplot as plt

# %%
# now we will take tow arrays of same size and plot a grapg of x=y
x=np.linspace(0,10,100)
y=x

# %%
# now we will plota nd simple graph of two array 
plt.plot(x,y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('straight line graph')
plt.show()

# %%
# now we will make a graph of x^2 (agraph of parabola)
x=np.linspace(-10,10,100)
y=x**2
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('y-axis')
plt.title('parabola graph')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# now we need to make graph of y=sin(x)
x=np.linspace(-10,10,100)
y=np.sin(x)
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('sin graph')
plt.show()

# %%
# now we need to plot an graph of y=xlog(x)
x=np.linspace(1,10,100)
y=x*np.log(x)
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('x.log(x) graph')
plt.show()
