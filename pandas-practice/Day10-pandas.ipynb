# %%
import pandas as pd
import numpy as np

# %%
# now we need to convert the csv file into serice
df1=pd.read_csv('subs.csv').squeeze()

# %%
df1.head(10)
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# 5    46
# 6    33
# 7    40
# 8    44
# 9    74
# Name: Subscribers gained, dtype: int64

# %%
# now we do the same thing for the other csv file
df2=pd.read_csv('kohli_ipl.csv', index_col='match_no').squeeze()

# %%
df2
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
# now we will do the same with anoter dataset
pd.read_excel('bollywood.xlsx', index_col='movies').squeeze().head(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 # now we will do the same with anoter dataset
# ----> 2 pd.read_excel('bollywood.xlsx', index_col='movies').squeeze().head(10)
#
# File c:\Users\mrinm\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#     507 try:
# --> 508     data = io.parse(
#     509         sheet_name=sheet_name,
# ...

# %%
pd.read_excel('bollywood.xlsx', index_col='movie').squeeze().head(10)
# Out:
# movie
# Uri: The Surgical Strike                       Vicky Kaushal
# Battalion 609                                    Vicky Ahuja
# The Accidental Prime Minister (film)             Anupam Kher
# Why Cheat India                                Emraan Hashmi
# Evening Shadows                             Mona Ambegaonkar
# Soni (film)                             Geetika Vidya Ohlyan
# Fraud Saiyaan                                   Arshad Warsi
# Bombairiya                                      Radhika Apte
# Manikarnika: The Queen of Jhansi              Kangana Ranaut
# Thackeray (film)                         Nawazuddin Siddiqui
# Name: lead, dtype: object

# %%
pd.read_excel('bollywood.xlsx').head()
# Out:
#                                   movie              lead
# 0              Uri: The Surgical Strike     Vicky Kaushal
# 1                         Battalion 609       Vicky Ahuja
# 2  The Accidental Prime Minister (film)       Anupam Kher
# 3                       Why Cheat India     Emraan Hashmi
# 4                       Evening Shadows  Mona Ambegaonkar

# %%
pd.read_excel('bollywood.xlsx').columns
# Out:
# Index(['movie', 'lead'], dtype='object')

# %%
pd.read_excel('bollywood.xlsx', index_col='movie').squeeze().head(10)
